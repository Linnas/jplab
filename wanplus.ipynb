# %%
import requests
from pprint import pprint
import json

import pandas as pd
import numpy as np
import seaborn as sns

# %%
def send_post():

    url = "http://www.wanplus.com/ajax/stats/list"

    payload = "_gtk=1132691631&draw=1&columns%5B0%5D%5Bdata%5D=order&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=teamname&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=kda&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=true&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=killsPergame&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=true&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B4%5D%5Bdata%5D=deathsPergame&columns%5B4%5D%5Bname%5D=&columns%5B4%5D%5Bsearchable%5D=true&columns%5B4%5D%5Borderable%5D=true&columns%5B4%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B4%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B5%5D%5Bdata%5D=damagetoheroPermin&columns%5B5%5D%5Bname%5D=&columns%5B5%5D%5Bsearchable%5D=true&columns%5B5%5D%5Borderable%5D=true&columns%5B5%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B5%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B6%5D%5Bdata%5D=fstbloodpercentage&columns%5B6%5D%5Bname%5D=&columns%5B6%5D%5Bsearchable%5D=true&columns%5B6%5D%5Borderable%5D=true&columns%5B6%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B6%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B7%5D%5Bdata%5D=avgDuration&columns%5B7%5D%5Bname%5D=&columns%5B7%5D%5Bsearchable%5D=true&columns%5B7%5D%5Borderable%5D=true&columns%5B7%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B7%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B8%5D%5Bdata%5D=goldpermatch&columns%5B8%5D%5Bname%5D=&columns%5B8%5D%5Bsearchable%5D=true&columns%5B8%5D%5Borderable%5D=true&columns%5B8%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B8%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B9%5D%5Bdata%5D=goldsPermin&columns%5B9%5D%5Bname%5D=&columns%5B9%5D%5Bsearchable%5D=true&columns%5B9%5D%5Borderable%5D=true&columns%5B9%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B9%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B10%5D%5Bdata%5D=lasthitPermin&columns%5B10%5D%5Bname%5D=&columns%5B10%5D%5Bsearchable%5D=true&columns%5B10%5D%5Borderable%5D=true&columns%5B10%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B10%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B11%5D%5Bdata%5D=dragonkillsPergame&columns%5B11%5D%5Bname%5D=&columns%5B11%5D%5Bsearchable%5D=true&columns%5B11%5D%5Borderable%5D=true&columns%5B11%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B11%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B12%5D%5Bdata%5D=dragonkillspercentage&columns%5B12%5D%5Bname%5D=&columns%5B12%5D%5Bsearchable%5D=true&columns%5B12%5D%5Borderable%5D=true&columns%5B12%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B12%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B13%5D%5Bdata%5D=baronkillsPergame&columns%5B13%5D%5Bname%5D=&columns%5B13%5D%5Bsearchable%5D=true&columns%5B13%5D%5Borderable%5D=true&columns%5B13%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B13%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B14%5D%5Bdata%5D=baronkillspercentage&columns%5B14%5D%5Bname%5D=&columns%5B14%5D%5Bsearchable%5D=true&columns%5B14%5D%5Borderable%5D=true&columns%5B14%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B14%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B15%5D%5Bdata%5D=wardsplacedpermin&columns%5B15%5D%5Bname%5D=&columns%5B15%5D%5Bsearchable%5D=true&columns%5B15%5D%5Borderable%5D=true&columns%5B15%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B15%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B16%5D%5Bdata%5D=wardskilledpermin&columns%5B16%5D%5Bname%5D=&columns%5B16%5D%5Bsearchable%5D=true&columns%5B16%5D%5Borderable%5D=true&columns%5B16%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B16%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B17%5D%5Bdata%5D=wardskilledrate&columns%5B17%5D%5Bname%5D=&columns%5B17%5D%5Bsearchable%5D=true&columns%5B17%5D%5Borderable%5D=true&columns%5B17%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B17%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B18%5D%5Bdata%5D=towertakensPergame&columns%5B18%5D%5Bname%5D=&columns%5B18%5D%5Bsearchable%5D=true&columns%5B18%5D%5Borderable%5D=true&columns%5B18%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B18%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B19%5D%5Bdata%5D=towerdeathsPergame&columns%5B19%5D%5Bname%5D=&columns%5B19%5D%5Bsearchable%5D=true&columns%5B19%5D%5Borderable%5D=true&columns%5B19%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B19%5D%5Bsearch%5D%5Bregex%5D=false&order%5B0%5D%5Bcolumn%5D=2&order%5B0%5D%5Bdir%5D=desc&start=0&length=20&search%5Bvalue%5D=&search%5Bregex%5D=false&area=&eid=1015&type=team&gametype=2&filter=%7B%22team%22%3A%7B%7D%2C%22player%22%3A%7B%7D%2C%22meta%22%3A%7B%7D%7D"
    headers = {
        "Accept": "application/json, text/javascript, */*; q=0.01",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.9,zh-CN;q=0.8,zh;q=0.7",
        "Content-Length": "4719",
        "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Cookie": "wp_pvid=9477893127; UM_distinctid=174f378497123c-01faffd4ca431-333376b-1fa400-174f378497297d; gameType=2; wanplus_token=c36a7245346082823a1b63a8ccc2575e; wanplus_storage=lf4m67eka3o; wanplus_sid=70e50b66e8446b4509eeb224941a5e9b; isShown=1; downTip=1; wanplus_csrf=_csrf_tk_1115914415; wp_info=ssid=s1827501410; CNZZDATA1275078652=855025165-1586083275-%7C1615274506; Hm_lvt_f69cb5ec253c6012b2aa449fb925c1c2=1615161948,1615197513,1615248831,1615276885; Hm_lpvt_f69cb5ec253c6012b2aa449fb925c1c2=1615276885",
        "Host": "www.wanplus.com",
        "Origin": "http://www.wanplus.com",
        "Proxy-Connection": "keep-alive",
        "Referer": "http://www.wanplus.com/lol/teamstats",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.190 Safari/537.36",
        "X-CSRF-Token": "1132691631",
        "X-Requested-With": "XMLHttpRequest"
    }

    response = requests.request("POST", url, data=payload, headers=headers)

    if response.status_code == 200:
        data = json.loads(response.text)
    else:
        print(response.status_code)

    return data['data']

# %%
data = send_post()

# %%
exclude = ['heroFrequencyWinrate', 'damagetoheropercentage', 'goldpercentage', 'damagetakenpercentage', 'banHero', 'pickHero']
for item in data:
    keys = [*item.keys()]
    for key in keys:
        if key in exclude:
            del item[key]

# %%
lpl2021_s = pd.DataFrame(data)

# %%
del lpl2021_s['eid']

# %%
del lpl2021_s['teamid']

# %%
lpl2021_s.set_index('teamname', inplace=True)

# %%
lpl2021_s
# Out:
#          area appearedTimes  kda fstbloodpercentage proAppearedTimes  \
# teamname
# RNG         1            29  5.5              58.6%               29
# TES         0            24  4.9              66.7%               24
# EDG         1            25  4.6              64.0%               25
# WE          1            24  4.5              45.8%               24
# FPX         0            28  4.4              57.1%               28
# SN          0            23  4.3              52.2%               23
# LNG         1            25  3.7              44.0%               25
# RA          1            25  3.6              56.0%               25
# IG          1            27  3.6              55.6%               27
# JDG         0            25  3.6              44.0%               25
# V5          0            29  3.0              48.3%               29
# BLG         0            29  2.9              48.3%               29
# ...

# %%
lpl2021_s_cns = lpl2021_s.rename(columns={'area':'半区', 'appearedTimes':'场次', 'fstbloodpercentage':'一血率', 'proAppearedTimes':'正式场次', 'totalKills':'总击杀', 'totalDeaths':'总死亡', 'totalAssists':'总助攻', 'winrate':'胜率', 'teamWinrate':'队伍胜率', 'bo3Rate':'bo3率', 'fsttowerpercentage':'一塔率'})

# %%
lpl2021_s_cns.rename(columns={'totalLasthit':'总补刀', 'totalGolds':'总金币', 'totalDamagetohero':'总伤害', 'totalDamagetaken':'总承伤', 'totalWardsplaced':'总插眼数', 'totalWardskilled':'总击杀守卫数', 'totalDuration':'总时长', 'totalBarons':'总大龙数', 'totalDragon':'总小龙数', 'totalTowerTaken':'总推塔数', 'totalTowerDeath':'总被推塔数', 'totalHeronum':'总英雄数', 'goldsPermin':'分均经济', 'lasthitPermin':'分均补刀', 'damagetoheroPermin':'分均伤害'})
# Out:
#    teamname 半区  场次  kda    一血率 正式场次  总击杀  总死亡   总助攻    总补刀  ...         胜率  \
# 0       RNG  1  29  5.5  58.6%   29  465  298  1165  31739  ...   0.916667
# 1       TES  0  24  4.9  66.7%   24  397  256   859  24085  ...   0.727273
# 2       EDG  1  25  4.6  64.0%   25  361  260   844  28323  ...   0.818182
# 3        WE  1  24  4.5  45.8%   24  362  262   815  24876  ...   0.727273
# 4       FPX  0  28  4.4  57.1%   28  451  329  1000  28597  ...   0.692308
# 5        SN  0  23  4.3  52.2%   23  312  232   686  25816  ...   0.545455
# 6       LNG  1  25  3.7  44.0%   25  300  275   720  26207  ...   0.545455
# 7        RA  1  25  3.6  56.0%   25  345  308   778  29350  ...   0.727273
# 8        IG  1  27  3.6  55.6%   27  395  351   883  26489  ...        0.5
# 9       JDG  0  25  3.6  44.0%   25  368  341   852  26928  ...   0.666667
# 10       V5  0  29  3.0  48.3%   29  348  397   833  28495  ...   0.416667
# ...

# %%
wanted = ['kda', 'fstbloodpercentage',
       'goldsPermin', 'lasthitPermin', 'damagetoheroPermin',
       'wardsplacedpermin', 'wardskilledpermin', 'killsPergame',
       'deathsPergame', 'assistsPergame', 'damagetoheropermatch',
       'goldpermatch', 'lasthitpermatch', 'damagetakenpermatch',
       'baronkillsPergame', 'dragonkillsPergame', 'towertakensPergame',
       'towerdeathsPergame', 'wardsplacedPergame', 'wardskilledPergame',
       'highestgoldpermin', 'dragonkillspercentage', 'baronkillspercentage',
       'wardskilledrate', 'avgDuration', 'winrate', 'teamWinrate', 'bo3Rate',
       'fsttowerpercentage', 'goldearnedLead', 'fstbloodwinPercentage',
       'firsttowerwinPercentage', 'firstbaronwinPercentage',
       'baronbenefitPerkill', 'order']

# %%
used_columns = (lpl2021_s.columns
                  .isin(wanted))
lpl2021_s_abridged = lpl2021_s.loc[:, used_columns]
lpl2021_s_abridged.to_csv('lpl2021_spring_digest.csv')

# %%
lpl2021_s.to_csv('lpl2021_spring.csv')

# %%
attack_and_gold = ['KDA'] + attack_and_gold

# %%
lpl2021_s_abridged
# Out:
#           kda fstbloodpercentage goldsPermin lasthitPermin damagetoheroPermin  \
# teamname
# RNG       5.5              58.6%        1899          34.1               1939
# TES       4.9              66.7%        1924          34.2               2174
# EDG       4.6              64.0%        1861          34.5               1975
# WE        4.5              45.8%        1883          34.0               1965
# FPX       4.4              57.1%        1940          34.6               2183
# SN        4.3              52.2%        1814          34.3               2096
# LNG       3.7              44.0%        1776          33.7               1737
# RA        3.6              56.0%        1849          35.1               2195
# IG        3.6              55.6%        1832          33.1               2131
# JDG       3.6              44.0%        1843          33.8               2147
# V5        3.0              48.3%        1766          32.7               1832
# ...

# %%
lpl2021_s_abridged['fstbloodpercentage'] = lpl2021_s_abridged['fstbloodpercentage'].str.rstrip('%').astype('float') / 100.0
lpl2021_s_abridged['baronkillspercentage'] = lpl2021_s_abridged['baronkillspercentage'].str.rstrip('%').astype('float') / 100.0
lpl2021_s_abridged['wardskilledrate'] = lpl2021_s_abridged['wardskilledrate'].str.rstrip('%').astype('float') / 100.0
lpl2021_s_abridged['dragonkillspercentage'] = lpl2021_s_abridged['dragonkillspercentage'].str.rstrip('%').astype('float') / 100.0
# Out:
# <ipython-input-66-59a7f802793c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lpl2021_s_abridged['baronkillspercentage'] = lpl2021_s_abridged['baronkillspercentage'].str.rstrip('%').astype('float') / 100.0
# <ipython-input-66-59a7f802793c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lpl2021_s_abridged['wardskilledrate'] = lpl2021_s_abridged['wardskilledrate'].str.rstrip('%').astype('float') / 100.0
# <ipython-input-66-59a7f802793c>:3: SettingWithCopyWarning:
# ...

# %%
def convert_str(val):
    new_val = float(val.split(':')[0])*60 + float(val.split(':')[1])
    return new_val
lpl2021_s_abridged['avgDuration'] =  lpl2021_s_abridged['avgDuration'].apply(convert_str)
# Out:
# <ipython-input-79-182added20ab>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lpl2021_s_abridged['avgDuration'] =  lpl2021_s_abridged['avgDuration'].apply(convert_str)

# %%
lpl2021_s_abridged = lpl2021_s_abridged.astype('float')

# %%
corr_mtx = lpl2021_s_abridged.corr().stack().reset_index()

# %%
corr_mtx.rename(columns={0: 'correlation'}, inplace=True)

# %%
g = sns.relplot(
    data=corr_mtx,
    x="level_0", y="level_1", hue="correlation", size="correlation",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),
)

# Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")
